# %%
pip install transformers
# Out:
# ...
#    ---------------------------------------- 0.0/10.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.4 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/10.4 MB 15.2 MB/s eta 0:00:01
#    ------ --------------------------------- 1.6/10.4 MB 4.0 MB/s eta 0:00:03
#    -------- ------------------------------- 2.1/10.4 MB 4.4 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.9/10.4 MB 3.5 MB/s eta 0:00:03
#    ------------ --------------------------- 3.1/10.4 MB 3.1 MB/s eta 0:00:03
#    ------------- -------------------------- 3.4/10.4 MB 3.2 MB/s eta 0:00:03
#    ---------------- ----------------------- 4.2/10.4 MB 3.0 MB/s eta 0:00:03
#    ------------------- -------------------- 5.0/10.4 MB 3.0 MB/s eta 0:00:02
#    --------------------- ------------------ 5.5/10.4 MB 3.0 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.8/10.4 MB 3.0 MB/s eta 0:00:02
# ...

# %% [markdown]
# ## Import and Load Pretrained Summarization Model:

# %%
from transformers import pipeline

# Load summarization pipeline
summarizer = pipeline("summarization", model="facebook/bart-large-cnn")
# Out:
# config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# C:\Users\Vishal Kumar\AppData\Local\Programs\Python\Python313\Lib\site-packages\huggingface_hub\file_download.py:144: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Vishal Kumar\.cache\huggingface\hub\models--facebook--bart-large-cnn. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ...

# %%
text = """
Machine learning is a field of computer science that gives computers the ability to learn without being explicitly programmed.
It has become one of the most important fields of study and application in modern technology, enabling everything from self-driving cars to voice assistants like Siri and Alexa.
"""

# Summarize
summary = summarizer(text, max_length=50, min_length=25, do_sample=False)

print(summary[0]['summary_text'])
# Out:
# Machine learning is a field of computer science that gives computers the ability to learn without being explicitly programmed. It has become one of the most important fields of study and application in modern technology.
